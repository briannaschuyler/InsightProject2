# %%
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline

path='/Users/brianna/Documents/WL_DBdeets/'

# %%
# Read in the dataframe for one of the weeks
df = pd.read_csv(path+'2016-01-10 00:00:00to2016-01-17 00:00:00EvntsCollapsedByUser.csv', names = ['user','meetings'])

# %%
df.head(5)
# Out:
#                 user  meetings
# 0  22kwMh5aTdMJAFG9K        34
# 1  24HEFwdd5SLZtLJEE        10
# 2  24RYdjagZrRmyfP2Q        12
# 3  24h2QKgdzY2meH9xE         9
# 4  278eKoZSE3yvB3Mnh         3

# %%
# Plot number of meetings in a given week
plt.figure(figsize=(20,10))
n, bins, patches = plt.hist(df.meetings[df.meetings<100], 50, facecolor='green', alpha=0.75)

plt.xlabel('Number of Meetings Per Week (Week of 2016-01-10)', size=20)
